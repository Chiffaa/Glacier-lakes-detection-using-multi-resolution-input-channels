# %% [markdown]
# # For Colab

# %%
# !wget https://github.com/Chiffaa/Glacier-lakes-detection-using-multi-resolution-input-channels/archive/refs/heads/main.zip

# !unzip /content/main.zip

# %%
! pip install rasterio

# %%
! pip install wandb

# %%
# import kaggle.json file before
! mkdir  ~/.kaggle/
! cp kaggle.json ~/.kaggle/
! chmod 600 ~/.kaggle/kaggle.json

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# # Data Import

# %%
from data_loader import LakesDataset, get_loaders
from architecture import UNet, padding
from train import train, BATCH_SIZE, DEVICE, LEARNING_RATE
from utils import check_accuracy
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms.functional as F
import torch
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
batch_size = 32

# If the patch_size is given, and the data was still not preprocessed to this size, it is creating a new folder data_patch_size and uses it
train_dataset =LakesDataset(train=True, val=0.2, data_path = '../', patch_size = 1024)
val_dataset = LakesDataset(train=False, val=0.2, data_path = '../', patch_size=1024)
test_dataset =LakesDataset(train=False, data_path = '../', patch_size = 1024)

# %%
print(len(train_dataset))
print(len(val_dataset))
print(len(test_dataset))
# Out:
# 102
# 26
# 33

# %%
loaders = get_loaders(patch_size=512, data_path='../', val_split=0.2, batch_size=BATCH_SIZE, shuffle=True)

examples_train = iter(loaders['train_loader'])
samples_train, labels_train = next(examples_train)
print(samples_train.shape, labels_train.shape)
# Out:
# torch.Size([32, 3, 512, 512]) torch.Size([32, 1, 512, 512])

# %%
plt.figure(figsize=(25, 10))
for i in range(5):
    ax = plt.subplot(2, 5, i + 1)
    plt.imshow(samples_train[i+25].permute(1,2,0))
    plt.axis("off")
    ax = plt.subplot(2, 5, i + 6)
    plt.imshow(labels_train[i+25].permute(1,2,0))
    plt.axis("off")

# %% [markdown]
# # Train

# %%
model = UNet(in_channels=3, out_channels=1).to(DEVICE)
loss_fn = 'IoU'
optimizer = optim.Adam(model.parameters(), lr=LEARNING_RATE)

# %%
train(model, loaders, loss_fn, optimizer, epochs=10)
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: elena-golimblevskaya. Use `wandb login --relogin` to force relogin
# wandb version 0.15.1 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.14.2
# Run data is saved locally in <code>e:\OneDrive\Study\potsdam\Glacier lakes detection\Glacier-lakes-detection-using-multi-resolution-input-channels\wandb\run-20230503_174417-esws9c98</code>
# Syncing run <strong><a href='https://wandb.ai/elena-golimblevskaya/test_launch/runs/esws9c98' target="_blank">distinctive-yogurt-33</a></strong> to <a href='https://wandb.ai/elena-golimblevskaya/test_launch' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/elena-golimblevskaya/test_launch' target="_blank">https://wandb.ai/elena-golimblevskaya/test_launch</a>
#  View run at <a href='https://wandb.ai/elena-golimblevskaya/test_launch/runs/esws9c98' target="_blank">https://wandb.ai/elena-golimblevskaya/test_launch/runs/esws9c98</a>
#  27%|██▋       | 3/11 [05:22<14:20, 107.54s/it, loss=1]
# Waiting for W&B process to finish... <strong style="color:red">(failed 1).</strong> Press Ctrl-C to abort syncing.
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>batch</td><td>▁▅█</td></tr><tr><td>loss</td><td>▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>batch</td><td>2</td></tr><tr><td>loss</td><td>1.0</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">distinctive-yogurt-33</strong> at: <a href='https://wandb.ai/elena-golimblevskaya/test_launch/runs/esws9c98' target="_blank">https://wandb.ai/elena-golimblevskaya/test_launch/runs/esws9c98</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20230503_174417-esws9c98\logs</code>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# e:\OneDrive\Study\potsdam\Glacier lakes detection\Glacier-lakes-detection-using-multi-resolution-input-channels\demo.ipynb Cell 15 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/e%3A/OneDrive/Study/potsdam/Glacier%20lakes%20detection/Glacier-lakes-detection-using-multi-resolution-input-channels/demo.ipynb#X20sZmlsZQ%3D%3D?line=0'>1</a> train(model, loaders, loss_fn, optimizer, epochs=10)
#
# File e:\OneDrive\Study\potsdam\Glacier lakes detection\Glacier-lakes-detection-using-multi-resolution-input-channels\train.py:90, in train(model, loaders, loss_fn_name, optimizer, epochs, reduction)
#      87 loop = tqdm(loaders['train_loader'])
#      89 for batch_idx, (data, targets) in enumerate(loop):
# ---> 90     loss = train_fn(data, targets, model, optimizer, loss_fn, reduction)
#      91     loop.set_postfix(loss=loss) # update tqdm loop
#      92     train_log(loss, batch_idx)
#
# File e:\OneDrive\Study\potsdam\Glacier lakes detection\Glacier-lakes-detection-using-multi-resolution-input-channels\train.py:55, in train_fn(data, targets, model, optimizer, loss_fn, reduction)
#      52             loss = loss_fn(predictions, targets)
#      54 else:
# ---> 55     predictions = padding(model(data), data)
#      56     if reduction:
#      57             loss = loss_fn(predictions, targets, reduction=reduction)
#
# File c:\Users\Елена\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File e:\OneDrive\Study\potsdam\Glacier lakes detection\Glacier-lakes-detection-using-multi-resolution-input-channels\architecture.py:70, in UNet.forward(self, x)
#      68     x = down(x)
#      69     skip_connections.append(x)
# ---> 70     x = self.pool(x)
#      72 x = self.bottleneck(x)
#      74 skip_connections = skip_connections[::-1]
#
# File c:\Users\Елена\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File c:\Users\Елена\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\modules\pooling.py:166, in MaxPool2d.forward(self, input)
#     165 def forward(self, input: Tensor):
# --> 166     return F.max_pool2d(input, self.kernel_size, self.stride,
#     167                         self.padding, self.dilation, ceil_mode=self.ceil_mode,
#     168                         return_indices=self.return_indices)
#
# File c:\Users\Елена\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_jit_internal.py:484, in boolean_dispatch.<locals>.fn(*args, **kwargs)
#     482     return if_true(*args, **kwargs)
#     483 else:
# --> 484     return if_false(*args, **kwargs)
#
# File c:\Users\Елена\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\functional.py:782, in _max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode, return_indices)
#     780 if stride is None:
#     781     stride = torch.jit.annotate(List[int], [])
# --> 782 return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
#
# KeyboardInterrupt:

# %%
def iou_loss(pred, target):
    # Calculate intersection and union
    intersection = (pred * target).sum()
    union = pred.sum() + target.sum() - intersection

    # Calculate IoU
    iou = 1 - (intersection / union)

    # Return IoU loss
    return iou

# %%
val = iter(loaders['val_loader'])
samples_val, labels_val = next(examples_train)

# %%
preds_val = (padding(model(samples_val), samples_val) > 0.5).float()

# %%
np.unique(preds_val)
# Out:
# array([0.], dtype=float32)

# %%
preds_val = preds_val + (torch.rand((32, 1, 512, 512)) > 0.5).float()
plt.imshow(preds_val[0].permute(1,2,0))

# %%
np.unique(preds_val)
# Out:
# array([0., 1.], dtype=float32)

# %%
iou_loss(preds_val[0], labels_val[0])
# Out:
# tensor(0.9957)

# %%
plt.imshow(labels_val[0].permute(1,2,0))

# %%
(labels_val[0]).sum()
# Out:
# tensor(1196.)

# %%
(labels_val[0] * preds_val[0]).sum()
# Out:
# tensor(567.)

# %%
preds_val[0].sum()
# Out:
# tensor(131210.)

# %%
1 - (labels_val[0] * preds_val[0]).sum() / (preds_val[0].sum() + labels_val[0].sum() - (labels_val[0] * preds_val[0]).sum())
# Out:
# tensor(0.9957)

# %% [markdown]
# # Statistics

# %%
# Calculating white and black pixels in label
def pixel_count(label):
    return np.array([(label.sum()).item(), (label.sum()/label.numel()).item()])

# %%
def stats(patch_size=None):
    train_dataset =LakesDataset(train=True, data_path = '../', patch_size = patch_size)
    test_dataset =LakesDataset(train=False, data_path = '../', patch_size = patch_size)
    pixels_num = []
    for i in range(len(train_dataset)):
        pixels_num.append(pixel_count(train_dataset.__getitem__(i)[1]))

    for i in range(len(test_dataset)):
        pixels_num.append(pixel_count(test_dataset.__getitem__(i)[1]))

    return np.array(pixels_num).T

# %%
pixels_256 = stats(patch_size=256)
pixels_512 = stats(patch_size=512)
pixels_1024 = stats(patch_size=1024)
pixels = stats()

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 5))
data = [pixels_256[1], pixels_512[1], pixels_1024[1], pixels[1]][::-1]
colors = ['#ff4da6', '#d84dff', '#524dff', '#4dd8ff']

for i in range(4):
    ax[i].hist(data[i], bins=20, range=(0.0, 1.0), color=colors[i], edgecolor='black', linewidth=1.2, alpha=0.4)

plt.show()

# %%
from matplotlib.pyplot import figure
figure(figsize=(8, 6), dpi=90)
labels = ['original images', '1024x1024 images', '512x512 images', '256x256 images']
plt.hist(data, color=colors, edgecolor='black', linewidth=1.2, alpha=0.9)
plt.yscale('log')
plt.legend(labels)
plt.title("% of lakes area on logarithmic scale")
plt.show()

# %%
pixels_256_masked = stats(patch_size=256)
pixels_512_masked = stats(patch_size=512)
pixels_1024_masked = stats(patch_size=1024)
pixels_masked = stats()

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 5))
data_masked = [pixels_256_masked[1], pixels_512_masked[1], pixels_1024_masked[1], pixels_masked[1]][::-1]
colors = ['#ff4da6', '#d84dff', '#524dff', '#4dd8ff']

for i in range(4):
    ax[i].hist(data_masked[i], bins=20, range=(0.0, 1.0), color=colors[i], edgecolor='black', linewidth=1.2, alpha=0.4)

plt.show()

# %%
from matplotlib.pyplot import figure
figure(figsize=(8, 6), dpi=90)
labels = ['original images', '1024x1024 images', '512x512 images', '256x256 images']
plt.hist(data_masked, color=colors, edgecolor='black', linewidth=1.2, alpha=0.9)
plt.yscale('log')
plt.legend(labels)
plt.title("% of lakes area on logarithmic scale for images overlayed with mask")
plt.show()

# %%
pixels_256_masked
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# e:\OneDrive\Study\potsdam\Glacier lakes detection\Glacier-lakes-detection-using-multi-resolution-input-channels\demo.ipynb Cell 38 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/e%3A/OneDrive/Study/potsdam/Glacier%20lakes%20detection/Glacier-lakes-detection-using-multi-resolution-input-channels/demo.ipynb#X33sZmlsZQ%3D%3D?line=0'>1</a> pixels_256_masked
#
# NameError: name 'pixels_256_masked' is not defined
